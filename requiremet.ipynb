# %%
numpy
pandas 
scikit-learn
matplotlib
seaborn
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 numpy
#       2 pandas
#       3 scikit-learn
#
# NameError: name 'numpy' is not defined
